# %% [markdown]
# # Calculus with Python: Multivariable Calculus
#
# This tutorial introduces **multivariable calculus** using Python and [SymPy](https://www.sympy.org/). You'll learn how to compute **partial derivatives** and **multiple integrals** — key concepts when extending calculus to functions of several variables.
#
# ---

# %% [markdown]
# ## 1. Prerequisites
#
# Install SymPy:
#
# ```bash
# pip install sympy
# ```
#
# ---

# %% [markdown]
# ## 2. Functions of Several Variables
#
# A function of two variables:
# $$
# f(x, y) = x^2 + y^2
# $$
#
# ---

# %% [markdown]
# ## 3. Partial Derivatives
#
# The partial derivative of $ f(x, y) $ with respect to $ x $ is found by differentiating with respect to $ x $ while treating $ y $ as a constant.
#
# ### Example: Compute $ \frac{\partial}{\partial x} (x^2y + y^2) $

# %%
import sympy as sp

x, y = sp.symbols('x y')
f = x**2 * y + y**2
df_dx = sp.diff(f, x)
print(df_dx)  # Output: 2*x*y
# Out:
# 2*x*y

# %% [markdown]
# **With respect to $ y $:**

# %%
df_dy = sp.diff(f, y)
print(df_dy)  # Output: x**2 + 2*y
# Out:
# x**2 + 2*y

# %% [markdown]
# ## 4. Higher Order Partial Derivatives
#
# You can also take derivatives multiple times.
#
# ### Example: $ \frac{\partial^2 f}{\partial x \partial y} $

# %%
d2f_dxdy = sp.diff(f, x, y)
print(d2f_dxdy)  # Output: 2*x
# Out:
# 2*x

# %% [markdown]
# ## 5. Multiple Integrals
#
# ### 5.1. Double Integrals
#
# Compute the integral of $ f(x, y) $ over a region.
#
# #### Example: $ \int_0^1 \int_0^1 (x + y) \, dx\,dy $

# %%
integrand = x + y
result = sp.integrate(integrand, (x, 0, 1), (y, 0, 1))
print(result)  # Output: 1.0
# Out:
# 1

# %% [markdown]
# ### 5.2. Triple Integrals
#
# For a function $ f(x, y, z) $:

# %%
z = sp.symbols('z')
f3 = x + y + z
triple_int = sp.integrate(f3, (x, 0, 1), (y, 0, 1), (z, 0, 1))
print(triple_int)  # Output: 1.5
# Out:
# 3/2

# %% [markdown]
# ## 6. Visualizing Multivariable Functions
#
# SymPy can output data for plotting, but you can also use libraries like matplotlib for visualization.
#
# ### Example: Plot $ f(x, y) = x^2 + y^2 $

# %%
import numpy as np
import matplotlib.pyplot as plt

X, Y = np.meshgrid(np.linspace(-2, 2, 100), np.linspace(-2, 2, 100))
Z = X**2 + Y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## 7. Practice Problems
#
# 1. Find $ \frac{\partial}{\partial y} (e^{xy} \sin x) $.
# 2. Compute $ \int_0^2 \int_0^1 (3x^2 y) dx\,dy $.
# 3. Find all second order partial derivatives of $ f(x, y) = x^2 y^3 $.
# 4. Evaluate $ \int_0^1 \int_0^1 \int_0^1 (x + y + z)\,dx\,dy\,dz $.
#
# ---
#
# ## 8. References
#
# - [SymPy Calculus Documentation](https://docs.sympy.org/latest/tutorial/calculus.html)
# - [Khan Academy: Multivariable Calculus](https://www.khanacademy.org/math/multivariable-calculus)
#
# ---
#
# Explore the power of multivariable calculus with Python!

# %% [markdown]
# # [Calculus Context](./README.md)
